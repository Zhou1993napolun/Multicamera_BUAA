# %%
import cv2
import os
import json
import numpy as np
import ast



# 读取JSON文件
json_file_path = '/data02/zhangrunxiang/reid1/fast-reid/orange_demo/mv_video/0134_t0860to0945/matches.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)
    # print(type(data))
    

# 初始化记录结果的变量
matched_results = []

# 遍历每个帧数和视角下的预测结果
for frame, frame_data in data.items():
    min_distance = float('inf')  # 初始化最低相似距离为无穷大
    best_id = None
    best_view = None
    success =False

    for view, view_data in frame_data.items():
        person_id_rerank = view_data[0].split('_')[0]
        current_success = True if view_data[1] == "True" else False
        similarity_distance = float(view_data[2])

        if similarity_distance < min_distance:
            min_distance = similarity_distance
            best_id = person_id_rerank
            best_view = view
            success = current_success
            # print(frame, min_distance)

            # 判断是否记录结果
    if min_distance < 0.6 and success:
        matched_results.append({
            "frame": frame,
            "view": best_view,
            "best_id": best_id,
            "min_distance": min_distance    
            })

best_ids = best_ids = [result['best_id'] for result in matched_results]
# 打印满足条件的结果
for result in matched_results:
    print(result)
print("符合条件的结果数量为: ", len(matched_results))
# Out:
# {'frame': '0860', 'view': '2', 'best_id': '0134', 'min_distance': 0.3533547}
# {'frame': '0865', 'view': '3', 'best_id': '0134', 'min_distance': 0.29663634}
# {'frame': '0870', 'view': '3', 'best_id': '0134', 'min_distance': 1.1920929e-07}
# {'frame': '0875', 'view': '2', 'best_id': '0134', 'min_distance': 0.2040714}
# {'frame': '0880', 'view': '2', 'best_id': '0134', 'min_distance': 0.26792037}
# {'frame': '0885', 'view': '2', 'best_id': '0134', 'min_distance': 0.29394025}
# {'frame': '0890', 'view': '2', 'best_id': '0134', 'min_distance': 0.2652868}
# {'frame': '0895', 'view': '2', 'best_id': '0134', 'min_distance': 0.35096222}
# {'frame': '0900', 'view': '2', 'best_id': '0134', 'min_distance': 0.3315711}
# {'frame': '0905', 'view': '2', 'best_id': '0134', 'min_distance': 0.35916144}
# {'frame': '0910', 'view': '2', 'best_id': '0134', 'min_distance': 0.4105534}
# {'frame': '0915', 'view': '2', 'best_id': '0134', 'min_distance': 0.37725163}
# {'frame': '0920', 'view': '2', 'best_id': '0134', 'min_distance': 0.38082606}
# {'frame': '0925', 'view': '1', 'best_id': '0134', 'min_distance': 0.4276144}
# 符合条件的结果数量为:  14

# %%
import json
# 指定JSON文件路径
json_file_path = '/data02/zhangrunxiang/reid1/fast-reid/scripts/r2o.json'

# 加载JSON文件中的数据
with open(json_file_path, 'r') as file:
    json_data = json.load(file)

person_id_rerank = best_ids[0]
print(person_id_rerank)
person_id = json_data.get(person_id_rerank)#这里就把rerank的id变成了原始id
# print(person_id)

frame_numbers = []
for item in matched_results:
    frame_number = item['frame']  # 获取当前字典中的帧数信息
    frame_numbers.append(frame_number)  # 将帧数信息添加到列表中

# print(frame_numbers)


# 指定JSON文件目录路径
json_directory = '/data02/zhangrunxiang/reid1/datasets/Wildtrack_dataset_full/Wildtrack_dataset/annotations_positions/'

# 遍历matched_results，提取所有的帧数信息
# frame_numbers_to_search = set(item[1] for item in matched_results)
desired_position = {}  # 用于存储行人ID、帧数和视角为5的信息

for frame_number in frame_numbers:
    # 构建要查找的JSON文件名
    frame_number = str(frame_number)
    json_file_name = '0000' + frame_number + '.json'
    json_file_path = json_directory + json_file_name

    # 加载JSON文件中的数据
    with open(json_file_path, 'r') as file:
        json_data = json.load(file)
        desired_info = None
        person_id = int(person_id)
        for person_info in json_data:
            if person_info.get("personID") == person_id:
                for view_info in person_info.get("views", []):
                    if view_info.get("viewNum") == 5:  # 视角为5对应c6
                        desired_position[(frame_number)] = view_info
                        break
print("desired_position: ", desired_position)
# Out:
# 0134
# desired_position:  {'0860': {'viewNum': 5, 'xmax': 933, 'xmin': 904, 'ymax': 245, 'ymin': 123}, '0865': {'viewNum': 5, 'xmax': 889, 'xmin': 861, 'ymax': 243, 'ymin': 122}, '0870': {'viewNum': 5, 'xmax': 856, 'xmin': 828, 'ymax': 241, 'ymin': 121}, '0875': {'viewNum': 5, 'xmax': 815, 'xmin': 787, 'ymax': 238, 'ymin': 120}, '0880': {'viewNum': 5, 'xmax': 775, 'xmin': 747, 'ymax': 235, 'ymin': 119}, '0885': {'viewNum': 5, 'xmax': 748, 'xmin': 720, 'ymax': 233, 'ymin': 119}, '0890': {'viewNum': 5, 'xmax': 723, 'xmin': 695, 'ymax': 232, 'ymin': 118}, '0895': {'viewNum': 5, 'xmax': 701, 'xmin': 674, 'ymax': 230, 'ymin': 118}, '0900': {'viewNum': 5, 'xmax': 656, 'xmin': 629, 'ymax': 227, 'ymin': 117}, '0905': {'viewNum': 5, 'xmax': 639, 'xmin': 613, 'ymax': 226, 'ymin': 116}, '0910': {'viewNum': 5, 'xmax': 623, 'xmin': 597, 'ymax': 223, 'ymin': 116}, '0915': {'viewNum': 5, 'xmax': 613, 'xmin': 587, 'ymax': 221, 'ymin': 115}, '0920': {'viewNum': 5, 'xmax': 585, 'xmin': 559, 'ymax': 219, 'ymin': 114}, '0925': {'viewNum': 5, 'xmax': 569, 'xmin': 544, 'ymax': 217, 'ymin': 114}}

# %%
import cv2
import os
import shutil

# 指定要处理的图像文件路径和保存路径
file_path = '/data02/zhangrunxiang/reid1/datasets/Wildtrack_dataset_full/Wildtrack_dataset/Image_subsets/C6/'
save_path = '/data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0134/'

# 创建保存路径文件夹
os.makedirs(save_path, exist_ok=True)

start_frame = 860
end_frame = 930
step = 5


# 复制文件到目标路径,视角下对应帧数图片复制到目标路径
for video_frame in range(start_frame, end_frame+1, step):
    source_file = os.path.join(file_path, f'{video_frame:08d}.png')  # 根据序号生成源文件路径
    destination_file = os.path.join(save_path, f'{video_frame:08d}.png')  # 根据序号生成目标文件路径
    shutil.copy(source_file, destination_file)
print("所有图片已成功复制到路径:", save_path)

# 遍历desired_position中所有帧数信息
for frame_number, info in desired_position.items():
    frame_number = str(frame_number)
    # 构建图像文件名
    image_filename = '0000' + frame_number + '.png'
    image_path = file_path + image_filename

    # 加载图像
    image = cv2.imread(image_path)

    # 获取坐标信息
    xmin = info['xmin']
    ymin = info['ymin']
    xmax = info['xmax']
    ymax = info['ymax']

    # 在图像上绘制矩形框
    cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)

    # 构建保存路径和文件名
    save_filename =  image_filename
    save_image_path = os.path.join(save_path, save_filename)

    # 保存带有框的图像
    cv2.imwrite(save_image_path, image, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])


print("带有框的图像已保存在路径:", save_path)
# Out:
# 所有图片已成功复制到路径: /data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0134/
# 带有框的图像已保存在路径: /data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0134/
