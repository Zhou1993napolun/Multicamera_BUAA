# %%
import cv2
import os
import json
import numpy as np
import ast



# 读取JSON文件
json_file_path = '/data02/zhangrunxiang/reid1/fast-reid/orange_demo/mv_video/0095_t0175to0300/matches.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)
    # print(type(data))
    

# 初始化记录结果的变量
matched_results = []

# 遍历每个帧数和视角下的预测结果
for frame, frame_data in data.items():
    min_distance = float('inf')  # 初始化最低相似距离为无穷大
    best_id = None
    best_view = None
    success =False

    for view, view_data in frame_data.items():
        person_id_rerank = view_data[0].split('_')[0]
        current_success = True if view_data[1] == "True" else False
        similarity_distance = float(view_data[2])

        if similarity_distance < min_distance:
            min_distance = similarity_distance
            best_id = person_id_rerank
            best_view = view
            success = current_success
            # print(frame, min_distance)

            # 判断是否记录结果
    if min_distance < 0.4 and success:
        matched_results.append({
            "frame": frame,
            "view": best_view,
            "best_id": best_id,
            "min_distance": min_distance    
            })

best_ids = best_ids = [result['best_id'] for result in matched_results]
# 打印满足条件的结果
for result in matched_results:
    print(result)
print("符合条件的结果数量为: ", len(matched_results))
# Out:
# {'frame': '0180', 'view': '3', 'best_id': '0095', 'min_distance': 0.20049727}
# {'frame': '0185', 'view': '3', 'best_id': '0095', 'min_distance': 0.15153426}
# {'frame': '0190', 'view': '3', 'best_id': '0095', 'min_distance': 0.16891468}
# {'frame': '0195', 'view': '3', 'best_id': '0095', 'min_distance': 0.20642841}
# {'frame': '0200', 'view': '3', 'best_id': '0095', 'min_distance': 0.19614547}
# {'frame': '0205', 'view': '3', 'best_id': '0095', 'min_distance': 0.21556675}
# {'frame': '0210', 'view': '2', 'best_id': '0095', 'min_distance': 5.9604645e-08}
# {'frame': '0215', 'view': '3', 'best_id': '0095', 'min_distance': 0.123328984}
# {'frame': '0220', 'view': '3', 'best_id': '0095', 'min_distance': 0.21101439}
# {'frame': '0225', 'view': '3', 'best_id': '0095', 'min_distance': 0.1698001}
# {'frame': '0230', 'view': '1', 'best_id': '0095', 'min_distance': 0.38049972}
# {'frame': '0235', 'view': '1', 'best_id': '0095', 'min_distance': 0.26013243}
# {'frame': '0240', 'view': '1', 'best_id': '0095', 'min_distance': 0.39452642}
# {'frame': '0245', 'view': '1', 'best_id': '0095', 'min_distance': 0.29265845}
# {'frame': '0250', 'view': '1', 'best_id': '0095', 'min_distance': 0.3935982}
# {'frame': '0255', 'view': '1', 'best_id': '0095', 'min_distance': 0.291525}
# {'frame': '0260', 'view': '1', 'best_id': '0095', 'min_distance': 0.26112413}
# {'frame': '0265', 'view': '1', 'best_id': '0095', 'min_distance': 0.28484088}
# {'frame': '0270', 'view': '1', 'best_id': '0095', 'min_distance': 0.31628567}
# {'frame': '0275', 'view': '1', 'best_id': '0095', 'min_distance': 0.3332622}
# {'frame': '0280', 'view': '1', 'best_id': '0095', 'min_distance': 0.24798042}
# {'frame': '0285', 'view': '1', 'best_id': '0095', 'min_distance': 0.36579478}
# {'frame': '0290', 'view': '1', 'best_id': '0095', 'min_distance': 0.29789293}
# {'frame': '0295', 'view': '1', 'best_id': '0095', 'min_distance': 0.34060568}
# {'frame': '0300', 'view': '1', 'best_id': '0095', 'min_distance': 0.3300748}
# 符合条件的结果数量为:  25

# %%
import json
# 指定JSON文件路径
json_file_path = '/data02/zhangrunxiang/reid1/fast-reid/scripts/r2o.json'

# 加载JSON文件中的数据
with open(json_file_path, 'r') as file:
    json_data = json.load(file)

person_id_rerank = best_ids[0]
person_id = json_data.get(person_id_rerank)#这里就把rerank的id变成了原始id
print(person_id_rerank)
# print(person_id)

frame_numbers = []
for item in matched_results:
    frame_number = item['frame']  # 获取当前字典中的帧数信息
    frame_numbers.append(frame_number)  # 将帧数信息添加到列表中

# print(frame_numbers)


# 指定JSON文件目录路径
json_directory = '/data02/zhangrunxiang/reid1/datasets/Wildtrack_dataset_full/Wildtrack_dataset/annotations_positions/'

# 遍历matched_results，提取所有的帧数信息
# frame_numbers_to_search = set(item[1] for item in matched_results)
desired_position = {}  # 用于存储行人ID、帧数和视角为1的信息

for frame_number in frame_numbers:
    # 构建要查找的JSON文件名
    frame_number = str(frame_number)
    json_file_name = '0000' + frame_number + '.json'
    json_file_path = json_directory + json_file_name

    # 加载JSON文件中的数据
    with open(json_file_path, 'r') as file:
        json_data = json.load(file)
        desired_info = None
        person_id = int(person_id)
        for person_info in json_data:
            if person_info.get("personID") == person_id:
                for view_info in person_info.get("views", []):
                    if view_info.get("viewNum") == 1:  # 视角为1对应c2
                        desired_position[(frame_number)] = view_info
                        break
print("desired_position: ", desired_position)
# Out:
# 0095
# desired_position:  {'0180': {'viewNum': 1, 'xmax': 872, 'xmin': 817, 'ymax': 195, 'ymin': 0}, '0185': {'viewNum': 1, 'xmax': 894, 'xmin': 838, 'ymax': 203, 'ymin': 1}, '0190': {'viewNum': 1, 'xmax': 905, 'xmin': 848, 'ymax': 211, 'ymin': 1}, '0195': {'viewNum': 1, 'xmax': 913, 'xmin': 854, 'ymax': 218, 'ymin': 2}, '0200': {'viewNum': 1, 'xmax': 929, 'xmin': 868, 'ymax': 229, 'ymin': 3}, '0205': {'viewNum': 1, 'xmax': 975, 'xmin': 913, 'ymax': 237, 'ymin': 3}, '0210': {'viewNum': 1, 'xmax': 955, 'xmin': 889, 'ymax': 250, 'ymin': 4}, '0215': {'viewNum': 1, 'xmax': 992, 'xmin': 925, 'ymax': 260, 'ymin': 5}, '0220': {'viewNum': 1, 'xmax': 998, 'xmin': 928, 'ymax': 274, 'ymin': 6}, '0225': {'viewNum': 1, 'xmax': 963, 'xmin': 887, 'ymax': 292, 'ymin': 9}, '0230': {'viewNum': 1, 'xmax': 975, 'xmin': 898, 'ymax': 302, 'ymin': 10}, '0235': {'viewNum': 1, 'xmax': 983, 'xmin': 902, 'ymax': 319, 'ymin': 11}, '0240': {'viewNum': 1, 'xmax': 991, 'xmin': 904, 'ymax': 342, 'ymin': 14}, '0245': {'viewNum': 1, 'xmax': 991, 'xmin': 897, 'ymax': 368, 'ymin': 16}, '0250': {'viewNum': 1, 'xmax': 987, 'xmin': 884, 'ymax': 406, 'ymin': 20}, '0255': {'viewNum': 1, 'xmax': 991, 'xmin': 883, 'ymax': 426, 'ymin': 23}, '0260': {'viewNum': 1, 'xmax': 973, 'xmin': 853, 'ymax': 471, 'ymin': 28}, '0265': {'viewNum': 1, 'xmax': 959, 'xmin': 826, 'ymax': 513, 'ymin': 32}, '0270': {'viewNum': 1, 'xmax': 956, 'xmin': 810, 'ymax': 562, 'ymin': 38}, '0275': {'viewNum': 1, 'xmax': 937, 'xmin': 769, 'ymax': 634, 'ymin': 46}, '0280': {'viewNum': 1, 'xmax': 926, 'xmin': 730, 'ymax': 724, 'ymin': 56}, '0285': {'viewNum': 1, 'xmax': 877, 'xmin': 642, 'ymax': 833, 'ymin': 68}, '0290': {'viewNum': 1, 'xmax': 820, 'xmin': 531, 'ymax': 973, 'ymin': 85}, '0295': {'viewNum': 1, 'xmax': 734, 'xmin': 347, 'ymax': 1203, 'ymin': 113}, '0300': {'viewNum': 1, 'xmax': 462, 'xmin': -169, 'ymax': 1600, 'ymin': 165}}

# %%
import cv2
import os
import shutil

# 指定要处理的图像文件路径和保存路径
file_path = '/data02/zhangrunxiang/reid1/datasets/Wildtrack_dataset_full/Wildtrack_dataset/Image_subsets/C2/'
save_path = '/data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0095/'

# 创建保存路径文件夹
os.makedirs(save_path, exist_ok=True)

start_frame = 175
end_frame = 300
step = 5


# 复制文件到目标路径,视角下对应帧数图片复制到目标路径
for video_frame in range(start_frame, end_frame+1, step):
    source_file = os.path.join(file_path, f'{video_frame:08d}.png')  # 根据序号生成源文件路径
    destination_file = os.path.join(save_path, f'{video_frame:08d}.png')  # 根据序号生成目标文件路径
    shutil.copy(source_file, destination_file)


print("所有图片已成功复制到路径:", save_path)

# 遍历desired_position中所有帧数信息
for frame_number, info in desired_position.items():
    # frame_number = str(frame_number)
    
    # 构建图像文件名
    image_filename = '0000' + str(frame_number) + '.png'
    image_path = file_path + image_filename

    # 加载图像
    image = cv2.imread(image_path)

    # 获取坐标信息
    xmin = info['xmin']
    ymin = info['ymin']
    xmax = info['xmax']
    ymax = info['ymax']

    # 在图像上绘制矩形框
    cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)

    # 构建保存路径和文件名
    save_filename =  image_filename
    save_image_path = os.path.join(save_path, save_filename)



    # # 保存带有框的图像
    # cv2.imwrite(save_image_path, image)

    # 保存带有框的图像，确保覆盖同名文件
    cv2.imwrite(save_image_path, image, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])


print("带有框的图像已保存在路径:", save_path)
# Out:
# 所有图片已成功复制到路径: /data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0095/
# 带有框的图像已保存在路径: /data02/zhangrunxiang/demo/baseline_image/mv_video_mindistance_gallery0095/
